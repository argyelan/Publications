# %% [markdown]
# ### Reading in ROI based "causal circuitry" based on Siddiqi et al. 2021

# %%
import numpy as np
import pandas as pd

siddiqi_table = np.loadtxt('/resources/Siddiqi/Desikan-Killiany-Atlas-Siddiqi_2021_NHB_CombinedMap.txt', dtype="i1,i1,i4,f4,S32,f4,f4,f4,f4,f4")
siddiqi_df = pd.DataFrame(siddiqi_table)
siddiqi_df.columns=['index', 'segid', 'nvox', 'volmm3', 'structure_name', 's_mean', 's_std', 's_min', 's_max', 's_range']
siddiqi_df['roi'] = siddiqi_df['structure_name'].str.decode(encoding='UTF-8').str.replace("-","_").str.replace("_Proper","")
siddiqi_df.iloc[42:90]
# Out:
#     index  segid  nvox   volmm3                      structure_name  s_mean  \
# 42     43     -1   143   1144.0                      b'CC_Anterior' -0.1122
# 43     44    -24   107    856.0                   b'ctx-lh-unknown' -0.0862
# 44     45    -23   386   3088.0                  b'ctx-lh-bankssts' -0.0096
# 45     46    -22   267   2136.0   b'ctx-lh-caudalanteriorcingulate' -0.0009
# 46     47    -21   894   7152.0       b'ctx-lh-caudalmiddlefrontal'  0.0466
# 47     48    -19   351   2808.0                    b'ctx-lh-cuneus'  0.0096
# 48     49    -18   233   1864.0                b'ctx-lh-entorhinal' -0.0757
# 49     50    -17  1281  10248.0                  b'ctx-lh-fusiform'  0.0154
# 50     51    -16  1665  13320.0          b'ctx-lh-inferiorparietal' -0.0004
# 51     52    -15  1905  15240.0          b'ctx-lh-inferiortemporal'  0.0153
# 52     53    -14   343   2744.0          b'ctx-lh-isthmuscingulate' -0.1030
# 53     54    -13  1389  11112.0          b'ctx-lh-lateraloccipital'  0.0269
# 54     55    -12  1085   8680.0      b'ctx-lh-lateralorbitofrontal' -0.0073
# 55     56    -11   604   4832.0                   b'ctx-lh-lingual'  0.0293
# 56     57    -10   762   6096.0       b'ctx-lh-medialorbitofrontal' -0.0920
# 57     58     -9  1559  12472.0            b'ctx-lh-middletemporal' -0.0753
# 58     59     -8   243   1944.0           b'ctx-lh-parahippocampal' -0.0680
# 59     60     -7   463   3704.0               b'ctx-lh-paracentral' -0.0326
# 60     61     -6   790   6320.0           b'ctx-lh-parsopercularis'  0.0728
# 61     62     -5   331   2648.0             b'ctx-lh-parsorbitalis' -0.0159
# 62     63     -4   497   3976.0          b'ctx-lh-parstriangularis'  0.0409
# 63     64     -3   209   1672.0             b'ctx-lh-pericalcarine'  0.0343
# 64     65     -2  1218   9744.0               b'ctx-lh-postcentral'  0.0117
# 65     66     -1   416   3328.0        b'ctx-lh-posteriorcingulate' -0.0246
# 66     67      0  1577  12616.0                b'ctx-lh-precentral'  0.0597
# 67     68      1  1370  10960.0                 b'ctx-lh-precuneus' -0.0360
# 68     69      2   333   2664.0  b'ctx-lh-rostralanteriorcingulate' -0.1355
# 69     70      3  2185  17480.0      b'ctx-lh-rostralmiddlefrontal'  0.0262
# 70     71      4  3266  26128.0           b'ctx-lh-superiorfrontal' -0.0420
# 71     72      5  1509  12072.0          b'ctx-lh-superiorparietal'  0.1054
# 72     73      6  1718  13744.0          b'ctx-lh-superiortemporal' -0.0344
# 73     74      7  1498  11984.0             b'ctx-lh-supramarginal'  0.0673
# 74     75      8   101    808.0               b'ctx-lh-frontalpole' -0.0798
# 75     76      9   278   2224.0              b'ctx-lh-temporalpole' -0.0684
# 76     77     10   173   1384.0        b'ctx-lh-transversetemporal' -0.0211
# 77     78     11  1010   8080.0                    b'ctx-lh-insula'  0.0185
# 78     79    -48   114    912.0                   b'ctx-rh-unknown' -0.0764
# 79     80    -47   318   2544.0                  b'ctx-rh-bankssts'  0.0005
# 80     81    -46   375   3000.0   b'ctx-rh-caudalanteriorcingulate'  0.0008
# 81     82    -45   764   6112.0       b'ctx-rh-caudalmiddlefrontal'  0.0647
# 82     83    -43   286   2288.0                    b'ctx-rh-cuneus'  0.0041
# 83     84    -42   187   1496.0                b'ctx-rh-entorhinal' -0.0814
# 84     85    -41  1449  11592.0                  b'ctx-rh-fusiform'  0.0071
# 85     86    -40  2023  16184.0          b'ctx-rh-inferiorparietal'  0.0021
# 86     87    -39  1607  12856.0          b'ctx-rh-inferiortemporal'  0.0075
# 87     88    -38   390   3120.0          b'ctx-rh-isthmuscingulate' -0.0900
# 88     89    -37  1467  11736.0          b'ctx-rh-lateraloccipital'  0.0173
# 89     90    -36  1083   8664.0      b'ctx-rh-lateralorbitofrontal'  0.0047
#
#      s_std   s_min   s_max  s_range                              roi
# 42  0.0306 -0.1589 -0.0280   0.1310                      CC_Anterior
# 43  0.0310 -0.1340  0.0062   0.1402                   ctx_lh_unknown
# 44  0.0313 -0.0541  0.0538   0.1078                  ctx_lh_bankssts
# 45  0.0439 -0.0847  0.0825   0.1672   ctx_lh_caudalanteriorcingulate
# 46  0.0805 -0.0833  0.1622   0.2455       ctx_lh_caudalmiddlefrontal
# 47  0.0438 -0.1055  0.0473   0.1527                    ctx_lh_cuneus
# 48  0.0292 -0.1255 -0.0106   0.1149                ctx_lh_entorhinal
# 49  0.0495 -0.0725  0.1109   0.1833                  ctx_lh_fusiform
# 50  0.0824 -0.1044  0.1524   0.2568          ctx_lh_inferiorparietal
# 51  0.0801 -0.1046  0.1509   0.2555          ctx_lh_inferiortemporal
# 52  0.0234 -0.1304  0.0013   0.1318          ctx_lh_isthmuscingulate
# 53  0.0284 -0.0320  0.0972   0.1292          ctx_lh_lateraloccipital
# 54  0.0531 -0.1224  0.0825   0.2049      ctx_lh_lateralorbitofrontal
# 55  0.0259 -0.0543  0.0596   0.1139                   ctx_lh_lingual
# 56  0.0260 -0.1532 -0.0305   0.1227       ctx_lh_medialorbitofrontal
# 57  0.0642 -0.1288  0.1226   0.2514            ctx_lh_middletemporal
# 58  0.0287 -0.1213 -0.0187   0.1025           ctx_lh_parahippocampal
# 59  0.0335 -0.0802  0.0451   0.1253               ctx_lh_paracentral
# 60  0.0437 -0.0267  0.1586   0.1853           ctx_lh_parsopercularis
# 61  0.0368 -0.0787  0.0633   0.1420             ctx_lh_parsorbitalis
# 62  0.0575 -0.0448  0.1438   0.1886          ctx_lh_parstriangularis
# 63  0.0065  0.0124  0.0428   0.0304             ctx_lh_pericalcarine
# 64  0.0471 -0.0843  0.1259   0.2102               ctx_lh_postcentral
# 65  0.0550 -0.1328  0.0547   0.1875        ctx_lh_posteriorcingulate
# 66  0.0631 -0.0596  0.1685   0.2281                ctx_lh_precentral
# 67  0.0699 -0.1272  0.1025   0.2297                 ctx_lh_precuneus
# 68  0.0187 -0.1607 -0.0928   0.0679  ctx_lh_rostralanteriorcingulate
# 69  0.0658 -0.1022  0.1502   0.2524      ctx_lh_rostralmiddlefrontal
# 70  0.0816 -0.1555  0.1296   0.2851           ctx_lh_superiorfrontal
# 71  0.0466  0.0234  0.1768   0.1534          ctx_lh_superiorparietal
# 72  0.0575 -0.1256  0.0503   0.1759          ctx_lh_superiortemporal
# 73  0.0668 -0.0901  0.1634   0.2535             ctx_lh_supramarginal
# 74  0.0123 -0.1077 -0.0575   0.0502               ctx_lh_frontalpole
# 75  0.0322 -0.1146 -0.0009   0.1137              ctx_lh_temporalpole
# 76  0.0161 -0.0506  0.0210   0.0716        ctx_lh_transversetemporal
# 77  0.0540 -0.1112  0.1122   0.2234                    ctx_lh_insula
# 78  0.0382 -0.1496  0.0311   0.1807                   ctx_rh_unknown
# 79  0.0362 -0.0676  0.0556   0.1232                  ctx_rh_bankssts
# 80  0.0418 -0.0854  0.0768   0.1622   ctx_rh_caudalanteriorcingulate
# 81  0.0689 -0.0415  0.1763   0.2178       ctx_rh_caudalmiddlefrontal
# 82  0.0420 -0.1102  0.0437   0.1539                    ctx_rh_cuneus
# 83  0.0245 -0.1260 -0.0345   0.0915                ctx_rh_entorhinal
# 84  0.0472 -0.0702  0.1047   0.1749                  ctx_rh_fusiform
# 85  0.0868 -0.1209  0.1604   0.2813          ctx_rh_inferiorparietal
# 86  0.0823 -0.1179  0.1492   0.2671          ctx_rh_inferiortemporal
# 87  0.0325 -0.1337  0.0173   0.1510          ctx_rh_isthmuscingulate
# 88  0.0268 -0.0336  0.0718   0.1054          ctx_rh_lateraloccipital
# 89  0.0622 -0.1192  0.1019   0.2211      ctx_rh_lateralorbitofrontal

# %% [markdown]
# ### Read in volume changes and EF ROI data

# %%
ectdf = pd.read_csv('/resources/ANALYSIS/ECT_DATA_LABELS_2022-06-14_1917.csv')
efvol_t = pd.read_csv('/resources/ANALYSIS/Roast30-oldchanges.csv')
efvol_tt=efvol_t.iloc[np.where(efvol_t['volume change'].notnull())].copy()
amp = ectdf[['Record ID','ECT 1 amplitude (in mA, i.e. 800 or 900 typically)', 'ECT device', 'Age in years', 'Sex at birth of the participant']].iloc[np.where(ectdf['Event Name']=='baseline_before_treatment')]
amp.columns=['Record ID','amp', 'device', 'age', 'sex']
efvol = pd.merge(efvol_tt, amp, left_on='Record ID', right_on='Record ID')
efvol['amp2']=[(900 if (efvol.device[i]=='Thymatron') else 800) if np.isnan(value) else value for i,value in enumerate(efvol.amp)]
efvol['amp3']=[900 if value=='Thymatron' else 800 for i,value in enumerate(efvol.device)]
efvol['ef_mix2']=efvol['ef_mix']*(efvol['amp2']/900)
efvol['ef_mix3']=efvol['ef_mix']*(efvol['amp3']/900)
charges_df = pd.read_csv('/resources/ANALYSIS/charges249.csv')
#efvol
# Out:
# /tmp/ipykernel_25/3983466209.py:1: DtypeWarning: Columns (13,35,36,37,52,104,163,167,174,176) have mixed types. Specify dtype option on import or set low_memory=False.
#   ectdf = pd.read_csv('/resources/ANALYSIS/ECT_DATA_LABELS_2022-06-14_1917.csv')

# %% [markdown]
# ### Merging with clinical data

# %%
efvol_sid_t = pd.merge(efvol, siddiqi_df, left_on='roi', right_on='roi')
efvol_sid_t['s_cohen']=efvol_sid_t['s_mean']/efvol_sid_t['s_std']
efvol_sid = pd.merge(efvol_sid_t, charges_df, left_on = 'Record ID', right_on = 'id')
efvol_sid['efmix3_w']=efvol_sid['ef_mix3']*efvol_sid['total charge']
ix=np.where(ectdf['Event Name'].isin(['baseline_before_treatment', 'after_treatment']))
clinical = ectdf[['Record ID','Event Name','MADRS to HDRS17 conversion']].iloc[ix]
clinical.columns=['Record ID', 'Event Name', 'HDRS17']
clinical_wide = clinical.pivot(index='Record ID', columns='Event Name', values='HDRS17')
#clinical_wide['Record ID'] = clinical_wide.index #NEM KELL COLUMNA tenni mert ambigious
clinical_wide
clinical_wide
efvol_sid_hamd_t = pd.merge(efvol_sid_t, clinical_wide, left_on = 'Record ID', right_on = 'Record ID')
#efvol_sid_hamd_t
efvol_sid_hamd_t['Hamd change']=efvol_sid_hamd_t['after_treatment']-efvol_sid_hamd_t['baseline_before_treatment']
efvol_sid_hamd_t['Hamd change percent']=efvol_sid_hamd_t['Hamd change']/efvol_sid_hamd_t['baseline_before_treatment']
efvol_sid_hamd2 = efvol_sid_hamd_t.iloc[np.where((efvol_sid_hamd_t['Hamd change percent'].notnull()) & (efvol_sid_hamd_t['Record ID']!='G129431'))].copy().reset_index(drop=True)
efvol_sid_hamd2['nECT']=efvol_sid_hamd2['Number of right unilateral stimulations'] + efvol_sid_hamd2['Number of bi-temporal stimulations']
efvol_sid_hamd2['pmnt']=2
efvol_sid_hamd2.loc[np.where(efvol_sid_hamd2['Number of bi-temporal stimulations']==0)[0],'pmnt']=0
efvol_sid_hamd2.loc[np.where(efvol_sid_hamd2['Number of right unilateral stimulations']==0)[0],'pmnt']=1
efvol_sid_hamd2['nECT'] = efvol_sid_hamd2['Number of right unilateral stimulations'] + efvol_sid_hamd2['Number of bi-temporal stimulations']
efvol_sid_hamd2['efNECT'] = efvol_sid_hamd2['nECT'] * efvol_sid_hamd2['ef_mix3']
efvol_sid_hamd2['speed'] = efvol_sid_hamd2['Hamd change percent']/efvol_sid_hamd2['nECT']
efvol_sid_hamd2['Record ID'].unique().size
# Out:
# 386

# %% [markdown]
# #### General demographic

# %%
import matplotlib.pyplot as plt
efvol_sid_hamd = efvol_sid_hamd_t.iloc[np.where((efvol_sid_hamd_t['Hamd change percent'].notnull()) & (efvol_sid_hamd_t['Record ID']!='G129431'))].copy()
efvol_sid_hamd['Record ID'].unique().size
efvol_sid_hamd['ind']=2
efvol_sid_hamd['ind'].iloc[np.where(efvol_sid_hamd['Number of right unilateral stimulations']==0)]=1
efvol_sid_hamd['ind'].iloc[np.where(efvol_sid_hamd['Number of bi-temporal stimulations']==0)]=0               
#clinical_wide
print(efvol_sid_hamd['Record ID'].iloc[np.where(efvol_sid_hamd['ind']==0)].unique().size)
print(efvol_sid_hamd['Record ID'].iloc[np.where(efvol_sid_hamd['ind']==1)].unique().size)
print(efvol_sid_hamd['Record ID'].iloc[np.where(efvol_sid_hamd['ind']==2)].unique().size)
#Demographic

#ixdt = np.where(ectdf['Event Name']=='during_treatment')
ixdt = np.where(ectdf['Event Name']=='after_treatment')
#ectdf.columns[1:100]
meddf = ectdf[['Record ID', 'Data Access Group','Antidepressant during ECT treatment', 'Antipsychotic medication during ECT treatment', 'Lithium medication during ECT treatment','Other mood stabilizers', 'Benzodiazepine medication during ECT treatment']].iloc[ixdt]

ixdt2 = np.where(ectdf['Event Name']=='baseline_before_treatment')
meddf2 = ectdf[['Record ID', 'Psychiatric diagnosis used for ECT indication (ICD-10 code)']].iloc[ixdt2]
efvol_sid_hamd.columns
temp = efvol_sid_hamd.iloc[np.where(efvol_sid_hamd['roi']=='Left_Caudate')].copy()

#meddf.iloc[np.where(meddf['Record ID'].isin(meddf['Record ID'].iloc[np.where(meddf['Record ID'].duplicated())]))]
#meddf                    
demog_t = temp.merge(meddf.drop_duplicates(subset = 'Record ID', keep = 'last'), how='left', on='Record ID')
demog = demog_t.merge(meddf2, how='left', on='Record ID')
demog['diag'] = [a[0:3] for a in demog[['Psychiatric diagnosis used for ECT indication (ICD-10 code)']].values.astype(str).squeeze()]
demog.columns
#demog['Data Access Group']
demog[['sex', 'age', 'Data Access Group']].groupby('Data Access Group').mean()
demog[['sex', 'age', 'Data Access Group']].groupby('Data Access Group').count()
demog.groupby('Data Access Group')[['age']].describe()
demog.groupby('Data Access Group')[['sex', 'Antidepressant during ECT treatment']].value_counts(normalize=True)
medout = demog[['Antidepressant during ECT treatment']].value_counts(normalize=False)
apout = demog[['Antipsychotic medication during ECT treatment']].value_counts(normalize=False)
benzout = demog[['Benzodiazepine medication during ECT treatment']].value_counts(normalize=False)
litout = demog[['Lithium medication during ECT treatment']].value_counts(normalize=False)
moodout = demog[['Other mood stabilizers']].value_counts(normalize=False)
diagout = demog[['diag']].value_counts(normalize=False)
placout = demog[['ind']].value_counts(normalize=False)


#demog.columns
from matplotlib.backends.backend_pdf import PdfPages
pp = PdfPages('/resources/REPORTS/demo_report.pdf')
#plt.figure()
plt.text(0.2,0.2,medout.to_string())
pp.savefig()
plt.close()

plt.text(0.2,0.2,apout.to_string())
pp.savefig()
plt.close()

plt.text(0.2,0.2,benzout.to_string())
pp.savefig()
plt.close()

plt.text(0.2,0.2,litout.to_string())
pp.savefig()
plt.close()

plt.text(0.2,0.2,moodout.to_string())
pp.savefig()
plt.close()

plt.text(0.2,0.2,diagout.to_string())
pp.savefig()
plt.close()

plt.text(0.2,0.2,placout.to_string())
pp.savefig()
plt.close()

t= demog[['age','baseline_before_treatment', 'Hamd change percent']].mean()
plt.text(0.2,0.2,t.to_string())
pp.savefig()
plt.close()
t =demog[['age','baseline_before_treatment', 'Hamd change percent','sex']].groupby('sex').mean()
plt.text(0.2,0.2,t.to_string())
pp.savefig()
plt.close()
t = demog[['age','baseline_before_treatment', 'Hamd change percent']].std()
plt.text(0.2,0.2,t.to_string())
pp.savefig()
plt.close()

t=demog[['age','baseline_before_treatment', 'Hamd change percent','sex']].groupby('sex').std()
plt.text(0.2,0.2,t.to_string())
pp.savefig()
plt.close()

pp.close()

demog['Data Access Group'].iloc[np.where(demog['Data Access Group'].isnull())] = 'JO'
temp2 = demog[['age','baseline_before_treatment', 'Hamd change percent','Data Access Group']].groupby('Data Access Group').mean()
temp = demog[['age','Data Access Group']].groupby('Data Access Group').count()
temp3 = demog[['ind','Data Access Group']].groupby('Data Access Group').value_counts()
temp.columns = ['N']
temp.merge(temp2,on='Data Access Group') #JO from a site not identified
#temp.N.sum()
#pd.pivot(temp3.to_frame(), index='Data Access Group',columns='ind', values='0')
hm=temp3.to_frame().reset_index().rename({0 : 'Np'}, axis=1)
hm
hm2 = hm.merge(temp, on ='Data Access Group')
sitedf = pd.pivot(hm2, index='Data Access Group', columns='ind', values = 'Np').merge(temp, on ='Data Access Group')
sitedf.to_html("/resources/REPORTS/Tables/Sites.html")
# Out:
# /tmp/ipykernel_25/4064517337.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   efvol_sid_hamd['ind'].iloc[np.where(efvol_sid_hamd['Number of right unilateral stimulations']==0)]=1
# /tmp/ipykernel_25/4064517337.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   efvol_sid_hamd['ind'].iloc[np.where(efvol_sid_hamd['Number of bi-temporal stimulations']==0)]=0
# 246
# 79
# 61
# /tmp/ipykernel_25/4064517337.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   demog['Data Access Group'].iloc[np.where(demog['Data Access Group'].isnull())] = 'JO'

# %%
demog['nECT'] = demog['Number of right unilateral stimulations'] + demog['Number of bi-temporal stimulations']
demog[['age','nECT','baseline_before_treatment', 'Hamd change percent','sex']].groupby('sex').count()
demog['nECT'].mean()
demog[['Antidepressant during ECT treatment','sex']].groupby('sex').value_counts(normalize=False)
#demog[['Antipsychotic medication during ECT treatment','sex']].groupby('sex').value_counts(normalize=False)
# Out:
# sex  Antidepressant during ECT treatment
# F    TCA                                    8
#      SNRI                                   5
#      SSRI                                   5
#      none                                   4
# M    none                                   5
#      TCA                                    3
#      SNRI                                   1
#      SSRI                                   1
# dtype: int64

# %%
demog['diag'] = [a[0:3] for a in demog[['Psychiatric diagnosis used for ECT indication (ICD-10 code)']].values.astype(str).squeeze()]
ix = np.where(efvol_sid_hamd2['roi']=='Left_Hippocampus')
df = efvol_sid_hamd2[['Hamd change percent','pmnt']].iloc[ix].reset_index()
df['Hamd change percent'].describe()
df['responders']=0
df.loc[np.where(df['Hamd change percent']<(-0.5))[0],'responders']=1
df.describe()
# Out:
#               index  Hamd change percent        pmnt  responders
# count    386.000000           386.000000  386.000000  386.000000
# mean   16368.500000            -0.590351    0.520725    0.652850
# std     9483.691924             0.349457    0.753062    0.476682
# min        6.000000            -1.076035    0.000000    0.000000
# 25%     8187.250000            -0.868841    0.000000    0.000000
# 50%    16368.500000            -0.689409    0.000000    1.000000
# 75%    24549.750000            -0.393015    1.000000    1.000000
# max    32731.000000             0.611111    2.000000    1.000000

# %%
pd.pivot_table(df, values=['Hamd change percent','responders'], columns='pmnt', aggfunc=['mean','std']).T
# Out:
#            Hamd change percent  responders
#      pmnt
# mean 0               -0.619644    0.670732
#      1               -0.633702    0.746835
#      2               -0.416072    0.459016
# std  0                0.333189    0.470906
#      1                0.333541    0.437603
#      2                0.385742    0.502453

# %% [markdown]
# ### Comparing results from Mulders et al. 2020 and Siddiqi et al. 2021

# %%
# Mulders paper
roi='Right_Hippocampus'
ix=np.where((efvol_sid_hamd['Record ID']=='G100104'))
a=efvol_sid_hamd2[['roi','s_mean']].iloc[ix]
a['muller']=np.nan
a.loc[np.where(a['roi']=='ctx_rh_precuneus')[0],'muller']=0.27
a.loc[np.where(a['roi']=='Right_Putamen')[0],'muller']=-0.26
a.loc[np.where(a['roi']=='ctx_lh_rostralanteriorcingulate')[0],'muller']=-0.21
a.loc[np.where(a['roi']=='ctx_rh_supramarginal')[0],'muller']=0.17
a.loc[np.where(a['roi']=='ctx_lh_rostralmiddlefrontal')[0],'muller']=-0.16
a.loc[np.where(a['roi']=='ctx_rh_caudalanteriorcingulate')[0],'muller']=0.16
a.loc[np.where(a['roi']=='ctx_rh_rostralanteriorcingulate')[0],'muller']=-0.11
a.loc[np.where(a['roi']=='ctx_rh_fusiform')[0],'muller']=0.11
a.loc[np.where(a['roi']=='ctx_lh_precuneus')[0],'muller']=0.11
a.loc[np.where(a['roi']=='ctx_lh_middletemporal')[0],'muller']=-0.11
a.loc[np.where(a['roi']=='ctx_lh_supramarginal')[0],'muller']=0.09
a.loc[np.where(a['roi']=='ctx_rh_frontalpole')[0],'muller']=0.06
a.loc[np.where(a['roi']=='ctx_lh_entorhinal')[0],'muller']=-0.06
a.loc[np.where(a['roi']=='ctx_rh_precentral')[0],'muller']=-0.05
a.loc[np.where(a['roi']=='ctx_lh_isthmuscingulate')[0],'muller']=-0.02
a.loc[np.where(a['roi']=='ctx_lh_fusiform')[0],'muller']=0.02
a.loc[np.where(a['roi']=='ctx_rh_parahippocampal')[0],'muller']=0.01
a=pd.concat([a,pd.DataFrame([['banks',-0.0096, -0.04]], columns=['roi','s_mean', 'muller'])], ignore_index=True)

from scipy.stats import pearsonr
sns.regplot(data=a, x='s_mean', y='muller')
ix = np.where(a['muller'].notnull())
#ix
pearsonr(a['s_mean'].iloc[ix], a['muller'].iloc[ix])
#print(a['roi'][42:85])
# Out:
# (0.33280507029446216, 0.17719198804799377)

# %%
#calculate some correaltions in Right Hippocampus
roi='Right_Hippocampus'
ix=np.where((efvol_sid_hamd['roi']==roi) & (efvol_sid_hamd['ind']<3))
ix0=np.where((efvol_sid_hamd['roi']==roi) & (efvol_sid_hamd['ind']==0))
ix1=np.where((efvol_sid_hamd['roi']==roi) & (efvol_sid_hamd['ind']==1))
ix2=np.where((efvol_sid_hamd['roi']==roi) & (efvol_sid_hamd['ind']==2))

print(len(ix[0]))
print(len(ix0[0]))
print(len(ix1[0]))
print(len(ix2[0]))

print(pearsonr(efvol_sid_hamd['ef_mix3'].iloc[ix],efvol_sid_hamd['age'].iloc[ix]))
print(pearsonr(efvol_sid_hamd['ef_mix3'].iloc[ix0],efvol_sid_hamd['age'].iloc[ix0]))
print(pearsonr(efvol_sid_hamd['ef_mix3'].iloc[ix1],efvol_sid_hamd['age'].iloc[ix1]))
print(pearsonr(efvol_sid_hamd['ef_mix3'].iloc[ix2],efvol_sid_hamd['age'].iloc[ix2]))
#efvol_sid_hamd.ind.unique()
print(efvol_sid_hamd['ef_mix3'].iloc[ix0].mean())
print(efvol_sid_hamd['ef_mix3'].iloc[ix1].mean())
print(efvol_sid_hamd['ef_mix3'].iloc[ix2].mean())
print(efvol_sid_hamd['ef_mix3'].iloc[ix0].std())
print(efvol_sid_hamd['ef_mix3'].iloc[ix1].std())
print(efvol_sid_hamd['ef_mix3'].iloc[ix2].std())
import scipy.stats as stats

stats.ttest_ind(efvol_sid_hamd['ef_mix3'].iloc[ix0],efvol_sid_hamd['ef_mix3'].iloc[ix1])
# Out:
# 386
# 246
# 79
# 61
# (-0.2510429110950474, 5.839462148505664e-07)
# (-0.35478416612817487, 1.0435175352612535e-08)
# (-0.17252631971973958, 0.1284025894524097)
# (-0.28228474579382573, 0.027514361516840877)
# 81.16003096975932
# 96.66816808000395
# 86.75817034124029
# 14.788496333744982
# 15.909177894119956
# 15.588875216290253
# Ttest_indResult(statistic=-7.959378087234495, pvalue=2.9616216478593723e-14)

# %% [markdown]
# ## Univariate analysis

# %%
dflist = list()
for i in range(0,3):
    ix = np.where(efvol_sid_hamd2['pmnt']==i)

    agg_data = pd.pivot_table(efvol_sid_hamd2.iloc[ix], values=['ef_mix3','volume change'], columns='roi', aggfunc=['mean','std']).T
    agg_data_ef = agg_data.loc['mean']/agg_data.loc['std']
    agg_data.loc['mean']['ef_mix3']

    if (i==0):
        dflist.append(agg_data.loc['mean'])
        dflist.append(agg_data_ef)
    else:
        dflist.append(agg_data.loc['mean'])
        dflist.append(agg_data_ef)

#sns.regplot(agg_data.loc['mean']['ef_mix3'],agg_data_ef['volume change'])
#pearsonr(agg_data.loc['mean']['ef_mix3'],agg_data_ef['volume change'])

# %%
#Tables for effect sizes

place = ['RUL', 'BT', 'MIX']
for i in range(0,3):
    df = pd.merge(dflist[(2*i)][['ef_mix3','volume change']], dflist[(2*i)+1]['volume change'], on='roi')
    df.columns = ['EF (V/m)',  'Volume change (%)', 'Volume change (Cohens d)']
    df['Volume change (%)'] = df['Volume change (%)'] * 100 
    print(df.describe())
    df.round(decimals=2).to_html("/resources/REPORTS/Tables/EFvsVOL-"+ place[i] +".html")
# Out:
#          EF (V/m)  Volume change (%)  Volume change (Cohens d)
# count   85.000000          85.000000                 85.000000
# mean    75.518226           1.200422                  0.698786
# std     36.723118           0.908143                  0.325833
# min     28.066378          -0.020562                 -0.018631
# 25%     45.820251           0.711287                  0.517039
# 50%     66.411337           0.956304                  0.665184
# 75%     95.613147           1.352077                  0.868557
# max    178.761654           6.265724                  1.851176
#          EF (V/m)  Volume change (%)  Volume change (Cohens d)
# count   85.000000          85.000000                 85.000000
# mean    84.567794           1.530596                  0.844188
# std     38.697409           1.289660                  0.437466
# min     20.971477          -0.080350                 -0.096776
# 25%     47.085564           0.818505                  0.563176
# 50%     87.103283           1.255582                  0.788095
# 75%    112.817094           1.754527                  1.076642
# max    165.730286           7.121380                  2.260589
#          EF (V/m)  Volume change (%)  Volume change (Cohens d)
# count   85.000000          85.000000                 85.000000
# mean    77.789217           1.474903                  0.811108
# std     29.844378           1.313312                  0.431776
# min     34.676256          -0.021433                 -0.018410
# 25%     55.954482           0.693828                  0.514083
# 50%     70.993886           1.242566                  0.803597
# 75%     94.819890           1.640143                  1.062765
# max    168.896624           8.370334                  2.143781

# %%
agg_data = pd.pivot_table(efvol_sid_hamd2, values=['ef_mix3','volume change'], columns='roi', aggfunc=['mean','std']).T
df = pd.merge(agg_data.loc['mean'],(agg_data.loc['mean']/agg_data.loc['std'])['volume change'], on='roi')
df.columns = ['EF (V/m)', 'Volume change (%)', 'Volume change (Cohens d)']
df['Volume change (%)'] = df['Volume change (%)'] * 100 
print(df.describe())
df.round(decimals=2).to_html("/resources/REPORTS/Tables/EFvsVOL-ALL.html")
# Out:
#          EF (V/m)  Volume change (%)  Volume change (Cohens d)
# count   85.000000          85.000000                 85.000000
# mean    77.729227           1.311373                  0.737485
# std     31.137458           1.023971                  0.339115
# min     36.229345          -0.016750                 -0.015459
# 25%     54.361600           0.704289                  0.528789
# 50%     66.463492           1.087905                  0.699940
# 75%     88.961577           1.445577                  0.922889
# max    174.535631           6.773439                  1.933659

# %%
ix = np.where(efvol_sid_hamd2['roi']=='Left_Hippocampus')
agg_data = pd.pivot_table(efvol_sid_hamd2.iloc[ix], values=['ef_mix3','volume change','nECT'], columns='pmnt', aggfunc=['mean','std']).T
agg_data
# Out:
#              ef_mix3       nECT  volume change
#      pmnt
# mean 0     48.996587  10.902439       0.016626
#      1     91.828642  14.316456       0.034680
#      2     68.689251  16.442623       0.034188
# std  0      8.747422   4.369495       0.019114
#      1     15.107709   6.209059       0.016568
#      2     13.392207   5.258405       0.020724

# %%
#plotting 
from nilearn import image
template_data =  image.get_data('/resources/template.nii.gz')

code = pd.read_csv('/resources/FsTutorial_AnatomicalROI_FreeSurferColorLUT.csv')
#code.struct_name.str.replace('-','_')
idx = np.where(code.struct_name.str.replace('-','_').str.replace('_Proper','').isin(efvol['roi'].unique()))[0]
code85 = code.iloc[idx].copy()
#code85

# %%
for n in range(0,6):#set to 6
    b_data =  template_data.copy().astype('float')
    if ((n%2)==0):
        myvec=dflist[n]['ef_mix3']
    else:
        myvec=dflist[n]['volume change']
    for i in np.unique(template_data):
        if (i!=0):
            ixs = np.where(template_data==i)
            regt = code85.struct_name.iloc[np.where(code85['struct_index']==i)].str.replace('-Proper','').str.replace('-','_')
            if (regt.size!=0):
                ixs2 = np.where(myvec.index==regt.values[0])
                if (ixs2[0].size==1):
                    
                    b_data[ixs] = (myvec.values[ixs2[0][0]])
                    
                else:
                    b_data[ixs] = 0
            else:
                b_data[ixs] = 0
    if (n==0):
        image_list_uv = image.new_img_like('/resources/template.nii.gz', b_data)
    else:
        image_list_uv = np.append(image_list_uv, image.new_img_like('/resources/template.nii.gz', b_data))

# %%
Xlong=efvol_sid_hamd2[['Record ID', 'roi','ef_mix3','volume change','age', 'Hamd change percent','pmnt','nECT']].iloc[np.where(efvol_sid_hamd2['pmnt']==0)]
Xwide=pd.pivot(Xlong, index='Record ID', columns= 'roi', values=['ef_mix3','volume change'])
Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
orreg_t = [i[1] for i in Xw.columns[1:86]]
orreg = pd.DataFrame(orreg_t).astype(str)[0].str.replace('_','-')
test = pd.DataFrame(orreg).astype('str')
ri = np.where(test[0].str.contains('rh-') | test[0].str.contains('Right-'))
ri[0].shape  
ix = np.where(efvol_sid_hamd2['roi'].isin(orreg[ri[0]].str.replace('-','_')))[0]
efvol_sid_hamd2['side'] = 'L'
efvol_sid_hamd2.loc[ix,'side'] = 'R'
# Out:
# /tmp/ipykernel_25/2424630780.py:3: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()

# %%
li = np.array(list(set(range(0,85))-set(ri[0])))

# %%
from nilearn import plotting
import matplotlib.pyplot as plt
import matplotlib

mycolor = ['blue','green','orange']
fig, axs = plt.subplot_mosaic("XXXBBBZZZ;YYYFFFZZZ;AAAJJJDDD;CCCKKKDDD;EEENNNHHH;GGGOOOHHH", figsize=(20,10))

#for n, (key,ax) in enumerate(axs.items()):
#for n, ax in enumerate([axs[i] for i in ['B','D','F','H','J','L']]):
for n, ax in enumerate([axs[i] for i in ['Z','D','H']]):
    sns.regplot(x=dflist[(2*n)]['ef_mix3'].values,y=dflist[(2*n)+1]['volume change'].values, ax=ax, scatter_kws={'color':mycolor[n]},line_kws={'color':mycolor[n]})
    #sns.regplot(x=dflist[(2*n)]['ef_mix3'].values[ri[0]],y=dflist[(2*n)+1]['volume change'].values[ri[0]], ax=ax)
    #sns.regplot(x=dflist[(2*n)]['ef_mix3'].values[li],y=dflist[(2*n)+1]['volume change'].values[li], ax=ax)
    
    print(str(n)+ ': ' + str(pearsonr(dflist[(2*n)]['ef_mix3'].values,dflist[(2*n)+1]['volume change'].values)))
    print(str(n)+ ': ' + str(pearsonr(dflist[(2*n)]['ef_mix3'].values[ri[0]],dflist[(2*n)+1]['volume change'].values[ri[0]])))
    print(str(n)+ ': ' + str(pearsonr(dflist[(2*n)]['ef_mix3'].values[li],dflist[(2*n)+1]['volume change'].values[li])))
    
for n, ax in enumerate([axs[i] for i in ['X','Y','A','C','E','G']]):
    plotting.plot_stat_map(image_list_uv[n], display_mode='x', cut_coords=[50,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar=False, colorbar=False, axes=ax)
for n, ax in enumerate([axs[i] for i in ['B','F','J','K','N','O']]):    
    plotting.plot_stat_map(image_list_uv[n], display_mode='y', cut_coords=[-30,5,30], cmap=plt.cm.jet, black_bg=False, symmetric_cbar=False, colorbar=True, axes=ax)
    
#plotting.plot_stat_map(image_siddiqi, display_mode='x', cut_coords=[50,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=axs['Z'])    

axs['H'].set_xlabel('EF (V/m)')
for c in ['H','D','Z']:
    axs[c].set_ylabel('Volume change (Cohen\'s d)')
    axs[c].spines['right'].set_visible(False)
    axs[c].spines['top'].set_visible(False)
fig.tight_layout()
#axs['Y'].axis('off')
fig.savefig("/resources/REPORTS/Figures/Figure-UNIV-EF-VOL.svg",format='svg')
# Out:
# 0: (0.29894855562860234, 0.005448960068701223)
# 0: (0.015641780967619548, 0.9216805539068321)
# 0: (0.11442774459478476, 0.4649946127470354)
# 1: (0.5045090028285031, 8.515598300435137e-07)
# 1: (0.4373093583563612, 0.0037801451358265995)
# 1: (0.5523114886693732, 0.00012306788631332984)
# 2: (0.3902342915969873, 0.00022247389270753652)
# 2: (0.3303346551349502, 0.03263140742756354)
# 2: (0.45094061775971206, 0.0024069851010100505)
# /opt/conda/envs/stat-rethink2-pymc3/lib/python3.9/site-packages/nilearn/plotting/img_plotting.py:300: FutureWarning: Default resolution of the MNI template will change from 2mm to 1mm in version 0.10.0
#   anat_img = load_mni152_template()
# /tmp/ipykernel_25/726489250.py:31: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### DeltaVOL~EF+age+nECT : Replication of Argyelan et al 2019

# %%
import statsmodels.api as sm
#res_roi = pd.DataFrame({'roi':'', 'r': [], 'p': []})
res_roi = pd.DataFrame({'roi':'', 'tef': [], 'ef': [], 'tage': [], 'age': [], 'tnECT': [], 'nECT': []})
for i, value in enumerate(efvol_sid_hamd2['roi'].unique()):
    ix=np.where(efvol_sid_hamd2['roi']==value)
    y = efvol_sid_hamd2['volume change'].iloc[ix]

    X = efvol_sid_hamd2[['ef_mix3','age','nECT']].iloc[ix]
    X = sm.add_constant(X)
    model = sm.OLS(y,X).fit()
    predictions = model.predict(X)
    mr = model.summary2()
    pef = mr.tables[1]['P>|t|'][1]
    pag = mr.tables[1]['P>|t|'][2]
    #pvo = mr.tables[1]['P>|t|'][3]
    pne = mr.tables[1]['P>|t|'][3]
    tef = mr.tables[1]['t'][1]
    tag = mr.tables[1]['t'][2]
    #tvo = mr.tables[1]['t'][3]
    tne = mr.tables[1]['t'][3]

    add = pd.DataFrame({'roi': value, 'tef': tef, 'ef': pef, 'tage':tag, 'age':pag, 'tnECT':tne, 'nECT':pne, 'F':float(mr.tables[0].loc[4,3])}, index=[i])
    res_roi = pd.concat([res_roi,add])
from statsmodels.stats.multitest import fdrcorrection
rejected, pcorrected = fdrcorrection(res_roi['ef'], alpha=0.05, method='p', is_sorted=False)
res_roi['pcorr']=pcorrected
res_roi.round({'tef':1, 'ef':4, 'tage':1, 'age': 2, 'tnECT':1, 'nECT':4, 'F':1, 'pcorr':4}).to_html("/resources/REPORTS/Tables/Table-VOLvsEF-nECT-age.html")
res_roi[0:42].round({'tef':1, 'ef':4, 'tage':1, 'age': 2, 'tnECT':1, 'nECT':4, 'F':1, 'pcorr':4})
# Out:
#                                roi  tef      ef  tage   age  tnECT    nECT  \
# 0           Left_Cerebellum_Cortex  0.6  0.5564   1.4  0.18    0.8  0.4117
# 1                    Left_Thalamus  1.4  0.1640   1.7  0.10    3.0  0.0029
# 2                     Left_Caudate  0.8  0.4106   2.0  0.05    3.8  0.0002
# 3                     Left_Putamen  1.6  0.1036   2.1  0.03    1.4  0.1540
# 4                    Left_Pallidum  1.3  0.1957   3.1  0.00    3.4  0.0008
# 5                       Brain_Stem -0.3  0.7785   1.0  0.33   -0.2  0.8231
# 6                 Left_Hippocampus  7.0  0.0000  -1.9  0.05    5.4  0.0000
# 7                    Left_Amygdala  9.2  0.0000   0.6  0.54    7.9  0.0000
# 8              Left_Accumbens_area  3.2  0.0016  -1.4  0.16    3.1  0.0021
# 9                   Left_VentralDC  0.3  0.7442   0.8  0.43    3.2  0.0013
# 10         Right_Cerebellum_Cortex  0.8  0.4371   1.8  0.08    0.8  0.4396
# 11                  Right_Thalamus  0.1  0.9117   1.7  0.08    3.3  0.0009
# 12                   Right_Caudate  0.2  0.8636   3.7  0.00    2.7  0.0077
# 13                   Right_Putamen  0.0  0.9886   1.6  0.11    2.5  0.0128
# 14                  Right_Pallidum  0.1  0.9507   3.6  0.00    3.1  0.0022
# 15               Right_Hippocampus  2.1  0.0329  -0.1  0.89    6.0  0.0000
# 16                  Right_Amygdala -0.2  0.8049   3.6  0.00   10.5  0.0000
# 17            Right_Accumbens_area  1.3  0.1864   0.6  0.57    4.6  0.0000
# 18                 Right_VentralDC -0.0  0.9611   1.3  0.20    1.7  0.0974
# 19  ctx_lh_caudalanteriorcingulate  1.0  0.3296   3.3  0.00    3.9  0.0001
# 20      ctx_lh_caudalmiddlefrontal -2.0  0.0415   2.9  0.00    2.4  0.0169
# 21                   ctx_lh_cuneus  3.2  0.0017   0.2  0.86    1.9  0.0650
# 22               ctx_lh_entorhinal  4.8  0.0000  -0.4  0.67    4.9  0.0000
# 23                 ctx_lh_fusiform  2.1  0.0346   2.1  0.03    4.0  0.0001
# 24         ctx_lh_inferiorparietal  0.5  0.6013   4.1  0.00    2.8  0.0052
# 25         ctx_lh_inferiortemporal  1.5  0.1369   2.9  0.00    3.1  0.0024
# 26         ctx_lh_isthmuscingulate  1.6  0.1213   0.2  0.85    1.3  0.1946
# 27         ctx_lh_lateraloccipital  0.4  0.7065   1.7  0.09    2.3  0.0219
# 28     ctx_lh_lateralorbitofrontal  2.3  0.0200   0.3  0.77    2.9  0.0040
# 29                  ctx_lh_lingual  1.2  0.2260   1.3  0.20    1.9  0.0522
# 30      ctx_lh_medialorbitofrontal  2.4  0.0184   1.1  0.28    4.2  0.0000
# 31           ctx_lh_middletemporal  1.3  0.1909   2.6  0.01    4.0  0.0001
# 32          ctx_lh_parahippocampal  1.3  0.1821  -0.0  1.00    3.7  0.0003
# 33              ctx_lh_paracentral  0.7  0.4839   1.5  0.12    2.3  0.0232
# 34          ctx_lh_parsopercularis -0.7  0.4700   2.7  0.01    2.6  0.0089
# 35            ctx_lh_parsorbitalis  2.0  0.0490  -0.4  0.67    2.2  0.0296
# 36         ctx_lh_parstriangularis  0.7  0.4599   1.8  0.07    3.9  0.0001
# 37            ctx_lh_pericalcarine  2.6  0.0085   1.6  0.10    2.7  0.0064
# 38              ctx_lh_postcentral -0.5  0.6467  -1.0  0.32    2.0  0.0459
# 39       ctx_lh_posteriorcingulate  2.5  0.0133   3.2  0.00    1.8  0.0692
# 40               ctx_lh_precentral -1.5  0.1229   2.0  0.05    3.0  0.0032
# 41                ctx_lh_precuneus  2.8  0.0061   2.4  0.02    1.3  0.2098
#
#        F   pcorr
# 0    0.8  0.8154
# 1    5.1  0.4593
# 2    7.3  0.7270
# 3    3.8  0.3670
# 4    8.8  0.4622
# 5    0.5  0.9419
# 6   42.8  0.0000
# 7   72.8  0.0000
# 8   11.2  0.0208
# 9    3.8  0.9324
# 10   1.2  0.7431
# 11   4.6  0.9579
# 12   6.8  0.9419
# 13   2.9  0.9886
# 14   7.2  0.9726
# 15  16.7  0.1634
# 16  42.4  0.9419
# 17   8.4  0.4622
# 18   1.4  0.9726
# 19   8.1  0.6501
# 20   6.0  0.1762
# 21   4.1  0.0208
# 22  23.4  0.0001
# 23  10.6  0.1634
# 24   8.5  0.8663
# 25   8.0  0.4309
# 26   1.2  0.4018
# 27   2.6  0.9324
# 28   6.8  0.1215
# 29   1.8  0.4895
# 30  10.9  0.1215
# 31   9.8  0.4622
# 32   6.9  0.4622
# 33   2.3  0.7731
# 34   4.6  0.7682
# 35   4.3  0.1984
# 36   7.1  0.7665
# 37   4.2  0.0720
# 38   1.7  0.9011
# 39   4.6  0.1026
# 40   4.6  0.4018
# 41   3.4  0.0574

# %%
#Replicated which one were used in Elife Paper
dfelife = pd.read_csv('/resources/REPORTS/ELIFE-20180829.csv')

ix = np.where((dfelife['btnum']==0) & (dfelife['rulnum']<=15) & (dfelife['rulnum']>=4) & (dfelife['id'].values!='G130994') & (dfelife['resp'].notnull()))
#N=151 - but only 136 shows overlap, so 250 total replication

efvol_sid_hamd2['elife']=0

ix2 = np.where((efvol_sid_hamd2['Record ID']).isin(dfelife['id'].iloc[ix].values))
efvol_sid_hamd2.loc[ix2[0],'elife']=1

import statsmodels.api as sm
#res_roi = pd.DataFrame({'roi':'', 'r': [], 'p': []})
res_roi = pd.DataFrame({'roi':'', 'tef': [], 'ef': [], 'tage': [], 'age': [], 'tnECT': [], 'nECT': []})
for i, value in enumerate(efvol_sid_hamd2['roi'].unique()):
    ix=np.where((efvol_sid_hamd2['roi']==value) & (efvol_sid_hamd2['elife']==0))
    y = efvol_sid_hamd2['volume change'].iloc[ix]

    X = efvol_sid_hamd2[['ef_mix3','age','nECT']].iloc[ix]
    X = sm.add_constant(X)
    model = sm.OLS(y,X).fit()
    predictions = model.predict(X)
    mr = model.summary2()
    pef = mr.tables[1]['P>|t|'][1]
    pag = mr.tables[1]['P>|t|'][2]
    #pvo = mr.tables[1]['P>|t|'][3]
    pne = mr.tables[1]['P>|t|'][3]
    tef = mr.tables[1]['t'][1]
    tag = mr.tables[1]['t'][2]
    #tvo = mr.tables[1]['t'][3]
    tne = mr.tables[1]['t'][3]

    add = pd.DataFrame({'roi': value, 'tef': tef, 'ef': pef, 'tage':tag, 'age':pag, 'tnECT':tne, 'nECT':pne, 'F':float(mr.tables[0].loc[4,3])}, index=[i])
    res_roi = pd.concat([res_roi,add])
from statsmodels.stats.multitest import fdrcorrection
rejected, pcorrected = fdrcorrection(res_roi['ef'], alpha=0.05, method='p', is_sorted=False)
res_roi['pcorr']=pcorrected
res_roi.round({'tef':1, 'ef':4, 'tage':1, 'age': 2, 'tnECT':1, 'nECT':4, 'F':1, 'pcorr':4}).to_html("/resources/REPORTS/Tables/Table-VOLvsEF-nECT-age-withoutN151.html")
res_roi[0:42]
# Out:
#                                roi       tef            ef      tage  \
# 0           Left_Cerebellum_Cortex  1.019941  3.087583e-01  2.136020
# 1                    Left_Thalamus  1.354732  1.767457e-01  1.553605
# 2                     Left_Caudate  0.551909  5.815119e-01  2.608342
# 3                     Left_Putamen  1.611592  1.083329e-01  2.614821
# 4                    Left_Pallidum  1.226885  2.210388e-01  3.200595
# 5                       Brain_Stem -0.468221  6.400411e-01  0.920649
# 6                 Left_Hippocampus  4.682269  4.692668e-06 -0.324766
# 7                    Left_Amygdala  7.521840  1.011176e-12  0.211486
# 8              Left_Accumbens_area  3.662700  3.055682e-04 -0.341391
# 9                   Left_VentralDC -0.317393  7.512148e-01  0.810254
# 10         Right_Cerebellum_Cortex  0.140469  8.884042e-01  2.151492
# 11                  Right_Thalamus  0.686846  4.928266e-01  1.022485
# 12                   Right_Caudate  0.698898  4.852759e-01  3.869689
# 13                   Right_Putamen -0.558845  5.767761e-01  2.158130
# 14                  Right_Pallidum  1.274448  2.037074e-01  2.824028
# 15               Right_Hippocampus  1.506991  1.330959e-01  0.040341
# 16                  Right_Amygdala -0.428644  6.685572e-01  2.657464
# 17            Right_Accumbens_area  1.396947  1.636885e-01  0.454627
# 18                 Right_VentralDC  0.359597  7.194573e-01  1.462893
# 19  ctx_lh_caudalanteriorcingulate  1.542958  1.241263e-01  2.849465
# 20      ctx_lh_caudalmiddlefrontal -1.048972  2.952203e-01  2.874955
# 21                   ctx_lh_cuneus  2.808165  5.382227e-03 -0.634765
# 22               ctx_lh_entorhinal  3.770872  2.037957e-04 -0.412955
# 23                 ctx_lh_fusiform  1.554772  1.212860e-01  1.389034
# 24         ctx_lh_inferiorparietal  0.562608  5.742140e-01  3.285293
# 25         ctx_lh_inferiortemporal  1.380022  1.688326e-01  2.801688
# 26         ctx_lh_isthmuscingulate  1.729336  8.500343e-02  0.366479
# 27         ctx_lh_lateraloccipital  0.772057  4.408219e-01  1.191858
# 28     ctx_lh_lateralorbitofrontal  2.021112  4.435142e-02  0.230817
# 29                  ctx_lh_lingual  1.066987  2.870237e-01  1.085266
# 30      ctx_lh_medialorbitofrontal  1.776279  7.692286e-02  1.456062
# 31           ctx_lh_middletemporal  1.214088  2.258785e-01  2.934329
# 32          ctx_lh_parahippocampal  0.226910  8.206820e-01 -1.049917
# 33              ctx_lh_paracentral  1.525315  1.284650e-01  1.370619
# 34          ctx_lh_parsopercularis -0.478803  6.325040e-01  2.122293
# 35            ctx_lh_parsorbitalis  1.739786  8.314733e-02 -0.370762
# 36         ctx_lh_parstriangularis  0.998769  3.188879e-01  1.666831
# 37            ctx_lh_pericalcarine  1.905201  5.792002e-02  1.626295
# 38              ctx_lh_postcentral -1.992383  4.743421e-02 -0.351359
# 39       ctx_lh_posteriorcingulate  2.779886  5.858037e-03  2.887342
# 40               ctx_lh_precentral -1.018038  3.096599e-01  2.021507
# 41                ctx_lh_precuneus  3.223121  1.439453e-03  1.887415
#
#          age     tnECT          nECT        F         pcorr
# 0   0.033665  0.051585  9.589010e-01   1.5500  5.483561e-01
# 1   0.121564  2.303095  2.210842e-02   3.5550  4.173161e-01
# 2   0.009655  3.475295  6.029956e-04   6.9260  7.845795e-01
# 3   0.009479  1.425207  1.553649e-01   4.7140  4.114004e-01
# 4   0.001552  3.212594  1.491026e-03   8.4780  4.878814e-01
# 5   0.358136 -0.283854  7.767607e-01   0.5103  7.985733e-01
# 6   0.745634  4.786126  2.935536e-06  19.7800  1.994384e-04
# 7   0.832683  6.940931  3.440520e-11  45.2500  8.594997e-11
# 8   0.733101  2.454116  1.481710e-02   8.6550  5.194659e-03
# 9   0.418577  2.982851  3.142930e-03   3.2790  8.661060e-01
# 10  0.032411  0.375785  7.074003e-01   1.7430  9.322760e-01
# 11  0.307556  2.480565  1.378719e-02   2.7170  7.480404e-01
# 12  0.000140  1.839410  6.705992e-02   6.7540  7.480404e-01
# 13  0.031886  2.537047  1.179806e-02   3.6360  7.845795e-01
# 14  0.005131  2.584481  1.032983e-02   6.0000  4.679763e-01
# 15  0.967854  5.727418  2.963634e-08  13.5300  4.114004e-01
# 16  0.008389  9.476484  2.313407e-18  33.1100  8.118194e-01
# 17  0.649779  3.696341  2.696688e-04   5.9140  4.114004e-01
# 18  0.144773  1.405745  1.610617e-01   1.4050  8.573691e-01
# 19  0.004750  3.140109  1.895338e-03   5.7960  4.114004e-01
# 20  0.004395  1.285779  1.997293e-01   3.6010  5.455157e-01
# 21  0.526172  1.317729  1.888202e-01   4.0400  5.532590e-02
# 22  0.680000  4.349356  2.001309e-05  13.8700  4.330658e-03
# 23  0.166079  3.639564  3.328214e-04   7.1310  4.114004e-01
# 24  0.001167  2.176722  3.045269e-02   5.5940  7.845795e-01
# 25  0.005488  2.771718  6.002401e-03   6.9610  4.114004e-01
# 26  0.714323  0.501709  6.163212e-01   1.0590  3.710975e-01
# 27  0.234465  2.168668  3.106652e-02   2.0900  7.126269e-01
# 28  0.817649  2.684265  7.762832e-03   4.8310  2.879934e-01
# 29  0.278866  1.239795  2.162325e-01   1.0570  5.421559e-01
# 30  0.146651  3.865806  1.417465e-04   7.9820  3.710975e-01
# 31  0.003659  3.538722  4.805806e-04   8.6530  4.878814e-01
# 32  0.294786  3.184789  1.635597e-03   4.1200  9.059477e-01
# 33  0.171743  1.093797  2.751138e-01   1.4060  4.114004e-01
# 34  0.034813  1.686796  9.291018e-02   2.4210  7.985733e-01
# 35  0.711134  1.738943  8.329578e-02   2.5560  3.710975e-01
# 36  0.096821  2.986683  3.105183e-03   4.8520  5.531728e-01
# 37  0.105167  2.639038  8.845081e-03   3.5650  3.282134e-01
# 38  0.725620  1.822535  6.958777e-02   1.8630  2.879934e-01
# 39  0.004231  0.841229  4.010366e-01   4.0320  5.532590e-02
# 40  0.044310  1.897605  5.891896e-02   2.7750  5.483561e-01
# 41  0.060282  0.370105  7.116229e-01   3.6290  2.039225e-02

# %%
ix=np.where((efvol_sid_hamd2['roi']=='Left_Hippocampus') & (efvol_sid_hamd2['elife']==1))
ix[0].shape
# Out:
# (136,)

# %%
def hue_regplot(data, x, y, hue, palette=None, **kwargs):
    from matplotlib.cm import get_cmap
    
    regplots = []
    
    levels = data[hue].unique()
    
    if palette is None:
        default_colors =  get_cmap('tab10')
        palette = {k: default_colors(i) for i, k in enumerate(levels)}
        
    for key in levels:
        regplots.append(
            sns.regplot(
                x = x,
                y = y,
                data = data[data[hue] == key],
                color = palette[key],
                **kwargs
            )
        )
    return regplots

# %% [markdown]
# #### Plotting the regions that has the most EF and most number of ECT sensitivity

# %%
res_roi.index=res_roi['roi']
for c in ['tef','tnECT','F']:#set to 6
    b_data =  template_data.copy().astype('float')
    myvec=res_roi[c]
    for i in np.unique(template_data):
        if (i!=0):
            ixs = np.where(template_data==i)
            regt = code85.struct_name.iloc[np.where(code85['struct_index']==i)].str.replace('-Proper','').str.replace('-','_')
            if (regt.size!=0):
                ixs2 = np.where(myvec.index==regt.values[0])
                if (ixs2[0].size==1):
                    
                    b_data[ixs] = (myvec.values[ixs2[0][0]])
                    
                else:
                    b_data[ixs] = 0
            else:
                b_data[ixs] = 0
    if (c=='tef'):
        image_list_efvol = image.new_img_like('/resources/template.nii.gz', b_data)
    else:
        image_list_efvol = np.append(image_list_efvol, image.new_img_like('/resources/template.nii.gz', b_data))

# %%
fig, axs = plt.subplot_mosaic("XXXBBBZZZ;YYYFFFKKK;AAAJJJDDD", figsize=(20,10))
fig.tight_layout()

for n, ax in enumerate([axs[i] for i in ['X','Y','A']]):
    plotting.plot_stat_map(image_list_efvol[n], display_mode='x', cut_coords=[-27,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar=False, colorbar=False, axes=ax)
for n, ax in enumerate([axs[i] for i in ['B','F','J']]):    
    plotting.plot_stat_map(image_list_efvol[n], display_mode='y', cut_coords=[-30,-15,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar=False, colorbar=False, axes=ax)
for n, ax in enumerate([axs[i] for i in ['Z','K','D']]):    
    plotting.plot_stat_map(image_list_efvol[n], display_mode='z', cut_coords=[-30,-15,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar=False, colorbar=True, axes=ax)
    
#plotting.plot_stat_map(image_siddiqi, display_mode='x', cut_coords=[50,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=axs['Z'])    

#axs['X'].axis('off')
#axs['Y'].axis('off')
fig.savefig("/resources/REPORTS/Figures/Figure-EF-nECT-pred-VOL.svg",format='svg')

# %% [markdown]
# ### Common Causal Map (Siddiqi 2021 et al)

# %%
import matplotlib.pyplot as plt
from nilearn import plotting
fig, axs = plt.subplot_mosaic("XXX;YYY;KKK", figsize=(20,8))
fig.tight_layout()
sidimg = nb.load('/resources/Siddiqi/Siddiqi_2021_NHB_CombinedMap.nii')
#new_image_1 = image.new_img_like('/resources/template.nii.gz', template_data)

#plt.rcParams['figure.figsize'] = (10,10);
plotting.plot_stat_map(sidimg, display_mode='z', cut_coords=[40,25,10,-10,-30], cmap=plt.cm.jet, threshold=0.05, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=axs['X'])
plotting.plot_stat_map(sidimg, display_mode='y', cut_coords=[40,25,10,-25,-40], cmap=plt.cm.jet, threshold=0.05, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=axs['Y'])
plotting.plot_stat_map(sidimg, display_mode='x', cut_coords=[60, 45,30,15,5], cmap=plt.cm.jet, threshold=0.05, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=axs['K'])

fig.savefig("/resources/REPORTS/Figures/Figure-Sidiqqi-voxel.svg",format='svg')

# %% [markdown]
# ### Unsupervised multivariate analysis on the right side (to avoid effects from assymetry in RUL)

# %%
Xlong=efvol_sid_hamd2[['Record ID', 'roi','ef_mix3','volume change','age', 'Hamd change percent','pmnt','nECT']].iloc[np.where(efvol_sid_hamd2['pmnt']==0)]
Xwide=pd.pivot(Xlong, index='Record ID', columns= 'roi', values=['ef_mix3','volume change'])
Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
orreg_t = [i[1] for i in Xw.columns[1:86]]
orreg = pd.DataFrame(orreg_t).astype(str)[0].str.replace('_','-')
test = pd.DataFrame(orreg).astype('str')
ri = np.where(test[0].str.contains('rh-') | test[0].str.contains('Right-'))
ri[0].shape
# Out:
# /tmp/ipykernel_25/2539282340.py:3: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
# (42,)

# %% [markdown]
# ## PCA Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
pcacomp=10
#eflist = np.append(np.array(range(0,85)),170)
eflist = np.array(range(0,85))
pcloads = np.empty((len(ri[0]),0),float)
pcs = []
outcome = []
strloads=[]
recordids=[]
ev10=[]
for j in ['onef','onvol']:
    if (j=='onef'):
        a='ef'
        #clist = eflist #use this when using both sides of ROIs
        clist = ri[0]
    else:
        a='vol'
        #clist = np.array(range(85,170))
        clist = ri[0] + 85
    for i in range(0,3):
        Xlong=efvol_sid_hamd2[['Record ID', 'roi','ef_mix3','volume change','age', 'Hamd change percent','pmnt','nECT']].iloc[np.where(efvol_sid_hamd2['pmnt']==i)]
        if (i==0):
            b='rul'
        elif (i==1):
            b='bt'
        else:
            b='mix'
        #Xlong
        Xwide=pd.pivot(Xlong, index='Record ID', columns= 'roi', values=['ef_mix3','volume change'])
        Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
        #Xw
        #Xw.dropna()
        recordids.append(Xw.iloc[:,0].values)
        X=Xw.iloc[:,1:(Xw.shape[1]-4)].values
        y =Xw.iloc[:,(Xw.shape[1]-4):Xw.shape[1]].values
        #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
        X_train=X[:,clist]
        y_train=y
        #KK=X_train
        if (j=='onef'):
            #sc=StandardScaler(with_mean=False, with_std=False)#just for testing that it does what it meant
            sc=StandardScaler()
        else:
            sc=StandardScaler()
        X_train = sc.fit_transform(X_train)
        #X_train.std(axis=0)

        pca = PCA(n_components = pcacomp)
        X_train = pca.fit_transform(X_train)
        #X_test = pca.transform(X_test)
        explained_variance = pca.explained_variance_ratio_
        ev10.append(pca.explained_variance_ratio_) #this is used for n comp =10
        #plt.plot(np.cumsum(pca.explained_variance_ratio_))
        #plt.plot(pca.explained_variance_ratio_)
        print('explained variance: ' + str(explained_variance))
        for k in range(0,pcacomp):
            pcloads=np.append(pcloads, np.transpose([pca.components_[k,:]]), axis=1)
            strloads.append([a + str(k) + b])
        pcs.append(X_train)
        outcome.append(y_train)
        
pcarun='new'
# Out:
# explained variance: [0.66779496 0.08037127 0.05297438 0.04491265 0.03063626 0.01761634
#  0.01333473 0.01093646 0.01049843 0.00785529]
# explained variance: [0.61136212 0.1099392  0.09615836 0.04018034 0.02212406 0.01744305
#  0.01204481 0.01112009 0.00872393 0.0084026 ]
# explained variance: [0.61694928 0.16762103 0.05870564 0.03307613 0.02725255 0.01478893
#  0.01179806 0.01062908 0.00733946 0.00643203]
# explained variance: [0.44167219 0.07782084 0.05995755 0.05184882 0.04358208 0.03523912
#  0.02490562 0.0208119  0.02039002 0.01785075]
# explained variance: [0.44848651 0.10153131 0.06247402 0.04594289 0.04040841 0.03198764
#  0.03114558 0.02632506 0.02139772 0.01829921]
# explained variance: [0.44620247 0.11300143 0.07156706 0.04284841 0.03661399 0.03190444
#  0.02972704 0.02571649 0.02188809 0.02025324]
# /tmp/ipykernel_25/4124789904.py:32: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
# /tmp/ipykernel_25/4124789904.py:32: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
# /tmp/ipykernel_25/4124789904.py:32: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
# /tmp/ipykernel_25/4124789904.py:32: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
# /tmp/ipykernel_25/4124789904.py:32: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
# /tmp/ipykernel_25/4124789904.py:32: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()

# %% [markdown]
# ### Checking elbow

# %%
labels = ['$\Delta$VOL RUL', '$\Delta$VOL BT', '$\Delta$VOL MIX', 'EF RUL', 'EF BT', 'EF MIX']
lines = ['','-']
for i in range(0,6):
    plt.plot(range(1,11),ev10[i]*100,'o-'+lines[(i//3)], label=labels[i])
    plt.ylabel('Explained variance (%)')
    plt.title('Explained variance in the first 10 PCs')
    plt.legend(loc='best')

# %%
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
pcacomp=2
#eflist = np.append(np.array(range(0,85)),170)
eflist = np.array(range(0,85))
pcloads = np.empty((len(ri[0]),0),float)
pcs = []
outcome = []
strloads=[]
recordids=[]
#ev10=[]
for j in ['onef','onvol']:
    if (j=='onef'):
        a='ef'
        #clist = eflist
        clist = ri[0]
    else:
        a='vol'
        #clist = np.array(range(85,170))
        clist = ri[0] + 85
    for i in range(0,3):
        Xlong=efvol_sid_hamd2[['Record ID', 'roi','ef_mix3','volume change','age', 'Hamd change percent','pmnt','nECT']].iloc[np.where(efvol_sid_hamd2['pmnt']==i)]
        if (i==0):
            b='rul'
        elif (i==1):
            b='bt'
        else:
            b='mix'
        #Xlong
        Xwide=pd.pivot(Xlong, index='Record ID', columns= 'roi', values=['ef_mix3','volume change'])
        Xw = Xwide.merge(Xlong[['Record ID', 'age', 'Hamd change percent','pmnt', 'nECT']].drop_duplicates(), on='Record ID').dropna()
        #Xw
        #Xw.dropna()
        recordids.append(Xw.iloc[:,0].values)
        X=Xw.iloc[:,1:(Xw.shape[1]-4)].values
        y =Xw.iloc[:,(Xw.shape[1]-4):Xw.shape[1]].values
        #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
        X_train=X[:,clist]
        y_train=y
        #KK=X_train
        if (j=='onef'):
            #sc=StandardScaler(with_mean=False, with_std=False)
            sc=StandardScaler()
        else:
            sc=StandardScaler()
        X_train = sc.fit_transform(X_train)
        #X_train.std(axis=0)

        pca = PCA(n_components = pcacomp)
        X_train = pca.fit_transform(X_train)
        #X_test = pca.transform(X_test)
        explained_variance = pca.explained_variance_ratio_
        #ev10.append(pca.explained_variance_ratio_) #this is used for n comp =10
        #plt.plot(np.cumsum(pca.explained_variance_ratio_))
        #plt.plot(pca.explained_variance_ratio_)
        print('explained variance: ' + str(explained_variance))
        for k in range(0,pcacomp):
            pcloads=np.append(pcloads, np.transpose([pca.components_[k,:]]), axis=1)
            strloads.append([a + str(k) + b])
        pcs.append(X_train)
        outcome.append(y_train)
        
pcarun='new'

# %%
#Loading correlations
#for i in range(0,6)
strloads2 = [i for sublist in strloads for i in sublist]

if pcarun=='new':
    pcloads[:,0] = (-1)*pcloads[:,0]
    pcloads[:,9] = (-1)*pcloads[:,9] #pc-s only unique up until a sign
    pcloads[:,11] = (-1)*pcloads[:,11] #pc-s only unique up until a sign
    pcarun='old'
plt.rcParams['figure.figsize'] = (7,7);
res=pd.DataFrame(pcloads)
#res.rename(columns={0:strloads[0][0],1:strloads[1][0],2:strloads[2][0],3:strloads[3][0],4:strloads[4][0],5:strloads[5][0],6:strloads[6][0],7:strloads[7][0],8:strloads[8][0],9:strloads[9][0],10:strloads[10][0],11:strloads[11][0]},inplace = True)
res.columns=strloads2
#res
sns.heatmap(res.corr(), cmap='bwr', center=0)
# Out:
# <AxesSubplot:>

# %%
#Plotting
roi=orreg[0]
#for i,roi in enumerate(orreg):
#ix = np.where(siddiqi_df['structure_name']==roi)
#print(ix)
slist = []
rl = np.array([siddiqi_df['structure_name'][i].decode('UTF-8') for i in range(0,siddiqi_df.shape[0])])
rl2 = pd.DataFrame(rl).replace('Left-Thalamus-Proper','Left-Thalamus').replace('Right-Thalamus-Proper','Right-Thalamus')
for i,roi in enumerate(orreg):
    ix = np.where(rl2==roi)
    if (len(ix[0]) != 0): 
        #print(ix[0][0])
        slist.append(siddiqi_df['s_mean'].iloc[ix[0][0]])
svec =  np.array(slist)
#svec.shape

# %%
#plotting 
from nilearn import image
template_data =  image.get_data('/resources/template.nii.gz')

code = pd.read_csv('/resources/FsTutorial_AnatomicalROI_FreeSurferColorLUT.csv')
#code.struct_name.str.replace('-','_')
idx = np.where(code.struct_name.str.replace('-','_').str.replace('_Proper','').isin(efvol['roi'].unique()))[0]
code85 = code.iloc[idx].copy()
#code85

# %%
import nibabel as nb
code85
tp = nb.load('/resources/template.nii.gz')
tp.affine
m = 0
for i in np.unique(template_data):
    if (i!=0):
        #print(i)
        ixs = np.where(template_data==i)
        centcoord = np.vstack(ixs).mean(axis=1)
        centcoord_mm = nb.affines.apply_affine(tp.affine, centcoord)
        regt = code85.struct_name.iloc[np.where(code85['struct_index']==i)].str.replace('-Proper','')
        if (regt.size!=0):
            ixs2 = np.where(orreg[ri[0]]==regt.values[0])
            if (ixs2[0].size==1):
                pcvals = (pcloads[ixs2[0][0],:])
                if m==0:
                    res = pd.DataFrame(columns=(['x','y','z']+['pc'+str(i) for i in range(0,12)]+['sid']))
                    res.loc[0] = np.concatenate([centcoord_mm, pcvals,svec[ri][ixs2[0]]])
                    m = m+1
                else:
                    #res = pd.concat(res,np.concatenate([centcoord_mm, pcvals]), ignore_index = True)
                    res.loc[m] = np.concatenate([centcoord_mm, pcvals,svec[ri][ixs2[0]]])
                    m = m+1

res
# Out:
#             x          y          z       pc0       pc1       pc2       pc3  \
# 0   23.930452 -61.088053 -36.844745  0.147331 -0.150973  0.159194 -0.114384
# 1   12.068009 -17.571983   6.556900  0.176427 -0.034048  0.174847  0.069021
# 2   13.730591   8.884511  10.075319  0.157920  0.118494  0.165570  0.118256
# 3   26.379341   2.456061  -1.411558  0.157614  0.210356  0.171332  0.128931
# 4   20.726070  -3.568093  -1.091440  0.171021  0.137061  0.173924  0.142090
# 5   26.696174 -21.405913 -14.230957  0.177901  0.078182  0.185108  0.057240
# 6   24.007775  -3.728863 -19.844995  0.159042  0.248222  0.181262  0.122276
# 7    9.298507  12.098332  -7.094820  0.169631 -0.035035  0.181715  0.098107
# 8   12.104368 -14.270883  -9.745750  0.179475 -0.044250  0.184005  0.070685
# 9    6.296188  20.585337  26.366569  0.171001  0.016730  0.176004  0.017946
# 10  38.019312  11.212431  48.794710  0.118789  0.047188  0.131928  0.035186
# 11   7.124086 -80.323656  18.177849  0.153614 -0.255048  0.107751 -0.339117
# 12  22.896552  -3.775090 -33.648996  0.153048  0.154142  0.172506  0.010167
# 13  35.744839 -38.339497 -24.187066  0.174131 -0.001307  0.173292 -0.106683
# 14  47.454148 -60.764978  33.973743  0.148713 -0.268058  0.102995 -0.126560
# 15  51.425572 -29.150740 -24.809332  0.156962  0.105753  0.172085 -0.022379
# 16   8.724294 -44.820716  16.496422  0.165480 -0.196196  0.141973 -0.190633
# 17  34.822412 -83.931780   1.859789  0.148299 -0.280704  0.113189 -0.294623
# 18  22.931751  31.816142 -18.383264  0.168427  0.180502  0.178856  0.106230
# 19  14.421552 -68.010139  -5.383206  0.156815 -0.241261  0.136378 -0.293399
# 20   6.268374  37.718530 -16.646403  0.166849 -0.032756  0.176498  0.022590
# 21  59.206963 -22.577090 -13.290951  0.116592  0.020126  0.078378  0.061921
# 22  22.943408 -29.875376 -16.819386  0.176942 -0.020545  0.175549 -0.057868
# 23   7.232314 -24.079872  56.411000  0.147271 -0.087224  0.127053 -0.198804
# 24  48.745754  15.607098  11.219265  0.146280  0.241516  0.149507  0.178097
# 25  44.115990  39.788991 -12.037680  0.116623  0.155240  0.142207  0.156978
# 26  48.834555  33.629698   6.136801  0.130121  0.132541  0.124606  0.170717
# 27  12.122155 -79.347868   6.300417  0.148216 -0.261431  0.110267 -0.353282
# 28  46.689473 -18.628376  42.468011  0.103586 -0.109923  0.140906  0.067396
# 29   6.823854 -18.790417  37.506032  0.168361 -0.082737  0.161179 -0.108306
# 30  40.432994  -6.487468  45.074649  0.098234 -0.052286  0.145315  0.107263
# 31  10.019617 -57.148628  38.020584  0.164256 -0.206494  0.135483 -0.303740
# 32   7.061781  36.506965   5.729255  0.169303  0.007910  0.178707  0.031458
# 33  34.186374  46.692881  17.653782  0.165105  0.133346  0.131740  0.078933
# 34  12.221852  30.751035  44.209350  0.147654  0.065717  0.170924 -0.067087
# 35  24.190635 -61.640736  53.051839  0.115680 -0.195019  0.126162 -0.252452
# 36  54.558741  -6.551091  -5.166439  0.165345  0.122061  0.141611  0.167436
# 37  56.639620 -28.291141  31.824138  0.161574 -0.166738  0.118688  0.010214
# 38   8.369220  65.273844 -10.843208  0.143388 -0.031324  0.160037 -0.066498
# 39  30.301516  15.597519 -35.567195  0.127003  0.198873  0.165045  0.081609
# 40  45.295327 -19.094393   7.744860  0.169290  0.097645  0.173870  0.121113
# 41  36.849978   1.527806  -1.804570  0.162768  0.224755  0.167462  0.162863
#
#          pc4       pc5       pc6       pc7       pc8       pc9      pc10  \
# 0   0.145405 -0.064530  0.081400  0.202873  0.103943  0.101917  0.151755
# 1   0.180848  0.085552  0.177529 -0.065373  0.152349 -0.027839  0.126509
# 2   0.139536  0.189226  0.132447 -0.143315  0.134590  0.098451  0.170781
# 3   0.140964  0.187071  0.125955 -0.028732  0.093407  0.064199  0.127810
# 4   0.153520  0.180956  0.101076 -0.066184  0.062135 -0.039754  0.088366
# 5   0.175052  0.113567  0.090698 -0.009990  0.044105 -0.249862  0.000018
# 6   0.146133  0.230755  0.130970 -0.160424  0.074261 -0.300911  0.126028
# 7   0.175703  0.083492  0.123180 -0.226111  0.104840 -0.197439  0.123281
# 8   0.188467  0.033759  0.118033 -0.033014  0.091373 -0.113829  0.035163
# 9   0.166657 -0.152219  0.168999 -0.071780  0.153794 -0.182988  0.184962
# 10  0.166560 -0.100057  0.175891  0.139251  0.181334  0.171390  0.168279
# 11  0.124971 -0.265140  0.150254  0.198930  0.169429  0.148692  0.144070
# 12  0.138703  0.205123  0.109017 -0.245291  0.064461 -0.331942  0.111270
# 13  0.167094  0.081268  0.186462 -0.059813  0.164921 -0.194737  0.175404
# 14  0.151121 -0.210084  0.163916  0.252593  0.193118  0.130588  0.188649
# 15  0.149154  0.138343  0.172981  0.001571  0.163155 -0.149031  0.191825
# 16  0.157250 -0.206778  0.143065 -0.072341  0.161974  0.065595  0.135448
# 17  0.153919 -0.207033  0.136918  0.253372  0.176138  0.070618  0.128885
# 18  0.143934  0.224527  0.135493 -0.233219  0.124423 -0.055492  0.178858
# 19  0.161844 -0.151944  0.174259  0.067842  0.173260  0.089045  0.139616
# 20  0.158491  0.130193  0.140039 -0.279656  0.138121 -0.227468  0.163136
# 21  0.095829  0.073065  0.178645  0.002236  0.153110 -0.108485  0.192962
# 22  0.169840  0.018589  0.145850 -0.183481  0.131234 -0.222941  0.149664
# 23  0.147594 -0.162419  0.185481  0.074764  0.170279  0.032479  0.138568
# 24  0.162533  0.053877  0.187955  0.018229  0.195223  0.068042  0.191315
# 25  0.137186  0.118086  0.117532 -0.131917  0.154395  0.116876  0.142104
# 26  0.138947  0.088368  0.171792  0.001998  0.192532  0.035485  0.176206
# 27  0.141393 -0.225407  0.118568  0.207923  0.144691  0.119776  0.118316
# 28  0.128970 -0.147464  0.160235  0.213206  0.160091  0.128973  0.174536
# 29  0.150003 -0.223075  0.161224 -0.005736  0.182750 -0.011914  0.161956
# 30  0.133494 -0.136741  0.186712  0.157579  0.199037  0.137304  0.174803
# 31  0.144296 -0.238519  0.181934  0.144991  0.183948  0.155313  0.151968
# 32  0.166353  0.020397  0.148469 -0.237244  0.116727 -0.305658  0.174294
# 33  0.176055  0.059486  0.166244  0.034643  0.200294  0.108042  0.166851
# 34  0.175777 -0.084745  0.186524  0.048143  0.197482  0.052681  0.171180
# 35  0.146648 -0.173134  0.150115  0.296281  0.178559  0.161107  0.172367
# 36  0.171503  0.067972  0.201100 -0.081323  0.181872 -0.127031  0.191125
# 37  0.161967 -0.172722  0.192814  0.126709  0.184754  0.139523  0.200378
# 38  0.126194  0.167621  0.084741 -0.193251  0.128570 -0.032109  0.105028
# 39  0.134174  0.200222  0.127295 -0.208467  0.119080 -0.247470  0.123112
# 40  0.179687  0.024462  0.170056  0.031231  0.168736  0.079306  0.118458
# 41  0.161146  0.142249  0.183909 -0.094162  0.181728 -0.173142  0.195745
#
#         pc11     sid
# 0  -0.165181 -0.0176
# 1  -0.156954 -0.0049
# 2  -0.075673 -0.0156
# 3  -0.133770  0.0104
# 4  -0.267261  0.0042
# 5  -0.312483 -0.1040
# 6  -0.209901 -0.0949
# 7  -0.147766 -0.1024
# 8  -0.273620 -0.0645
# 9   0.032498  0.0008
# 10  0.245484  0.0647
# 11  0.021596  0.0041
# 12 -0.252760 -0.0814
# 13 -0.220335  0.0071
# 14  0.004596  0.0021
# 15 -0.159259  0.0075
# 16  0.067421 -0.0900
# 17 -0.081843  0.0173
# 18  0.079159  0.0047
# 19 -0.148938  0.0271
# 20  0.002608 -0.1013
# 21 -0.032348 -0.0788
# 22 -0.215067 -0.0620
# 23  0.113823 -0.0186
# 24  0.174654  0.0975
# 25  0.075911  0.0110
# 26  0.108594  0.0753
# 27 -0.040067  0.0318
# 28  0.191783  0.0179
# 29  0.071528 -0.0204
# 30  0.180018  0.0600
# 31  0.102067 -0.0225
# 32  0.039368 -0.1301
# 33  0.224163  0.0492
# 34  0.216316 -0.0380
# 35  0.114337  0.1065
# 36 -0.042787 -0.0349
# 37  0.134322  0.0708
# 38  0.059270 -0.0816
# 39 -0.068029 -0.0759
# 40 -0.181560 -0.0409
# 41 -0.089646  0.0186

# %%
#sns.regplot(data=res, x='pc1',y='pc6')
X=res[['x','y','z','pc6','pc7']]#pc 6 and pc 7 are PC 1 and PC 2 respectively, just in different electrode placement 
y=res['sid']
X = sm.add_constant(X)
model = sm.OLS(y,X).fit()
predictions = model.predict(X)
mr = model.summary2()
mr
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.494
# Dependent Variable: sid              AIC:                -142.0162
# Date:               2023-05-01 23:11 BIC:                -131.5902
# No. Observations:   42               Log-Likelihood:     77.008
# Df Model:           5                F-statistic:        9.019
# Df Residuals:       36               Prob (F-statistic): 1.26e-05
# R-squared:          0.556            Scale:              0.0017454
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.0799     0.0370   -2.1607   0.0375   -0.1548   -0.0049
# x           0.0003     0.0006    0.5380   0.5939   -0.0009    0.0015
# y           0.0006     0.0003    2.0233   0.0505   -0.0000    0.0013
# z          -0.0003     0.0005   -0.5232   0.6040   -0.0013    0.0008
# pc6         0.4583     0.3065    1.4949   0.1437   -0.1634    1.0800
# pc7         0.3304     0.1026    3.2193   0.0027    0.1223    0.5386
# ------------------------------------------------------------------
# Omnibus:              1.311         Durbin-Watson:           2.035
# Prob(Omnibus):        0.519         Jarque-Bera (JB):        1.139
# Skew:                 -0.216        Prob(JB):                0.566
# Kurtosis:             2.319         Condition No.:           2001
# ==================================================================
# * The condition number is large (2e+03). This might indicate
# strong multicollinearity or other numerical problems.
# """

# %%
#myvec=pc1bt[0:85]
for n in range(0,12):
    b_data =  template_data.copy().astype('float')
    #myvec=pcloads[:,n+6]
    myvec=pcloads[:,n]
    for i in np.unique(template_data):
        if (i!=0):
            ixs = np.where(template_data==i)
            regt = code85.struct_name.iloc[np.where(code85['struct_index']==i)].str.replace('-Proper','')
            if (regt.size!=0):
                ixs2 = np.where(orreg[ri[0]]==regt.values[0])
                if (ixs2[0].size==1):
                    
                    b_data[ixs] = (myvec[ixs2[0][0]])
                    
                else:
                    b_data[ixs] = 0
            else:
                b_data[ixs] = 0
    if (n==0):
        image_list = image.new_img_like('/resources/template.nii.gz', b_data)
    else:
        image_list = np.append(image_list, image.new_img_like('/resources/template.nii.gz', b_data))

# %%
b_data =  template_data.copy().astype('float')
myvec=svec[ri]
for i in np.unique(template_data):
    if (i!=0):
        ixs = np.where(template_data==i)
        regt = code85.struct_name.iloc[np.where(code85['struct_index']==i)].str.replace('-Proper','')
        if (regt.size!=0):
            ixs2 = np.where(orreg[ri[0]]==regt.values[0])
            if (ixs2[0].size==1):
                b_data[ixs] = (myvec[ixs2[0][0]])
            else:
                b_data[ixs] = 0
        else:
            b_data[ixs] = 0
image_siddiqi = image.new_img_like('/resources/template.nii.gz', b_data)

# %%
from nilearn import plotting
import matplotlib.pyplot as plt

fig, axs = plt.subplot_mosaic("XXXYYYZZZ;AAACCCDDD;EEEGGGHHH;IIIKKKLLL", figsize=(20,10))
fig.tight_layout()
mycol = ['blue', 'blue', 'green','green', 'orange', 'orange']
#for n, (key,ax) in enumerate(axs.items()):
#for n, ax in enumerate([axs[i] for i in ['B','D','F','H','J','L']]):
for n, ax in enumerate([axs[i] for i in ['D','D','H','H','L','L']]):
    #n=11 #(n=7,9,11 are RUL, BT and MIX respectively)
    if (((n+6)%2)==1):
        sns.regplot(x=svec[ri],y=pcloads[:,(n+6)],ax=ax, scatter_kws={'color': mycol[n]}, line_kws={'color': mycol[n]})
    print(str(n+6)+ ': ' + str(pearsonr(svec[ri],pcloads[:,n+6])))
for n, ax in enumerate([axs[i] for i in ['A','C','E','G','I','K']]):    
    plotting.plot_stat_map(image_list[n+6], display_mode='x', cut_coords=[50,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=ax)
plotting.plot_stat_map(image_siddiqi, display_mode='x', cut_coords=[50,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=axs['Z'])    

axs['X'].axis('off')
axs['Y'].axis('off')
fig.savefig("/resources/REPORTS/Figures/Figure-VOL-PCA.svg",format='svg')
# Out:
# 6: (0.42280450276252224, 0.005278282332603579)
# 7: (0.6240840256425049, 1.0045343554306642e-05)
# 8: (0.5980416050287216, 2.8831573401709878e-05)
# 9: (0.6858385250520388, 5.374908346046354e-07)
# 10: (0.4392038872451213, 0.003614989710490133)
# 11: (0.46183168832298627, 0.0020784233980683108)

# %%
fig, axs = plt.subplot_mosaic("AAACCC;EEEGGG;IIIKKK", figsize=(20,10))
fig.tight_layout()
#for n, (key,ax) in enumerate(axs.items()):
#for n, ax in enumerate([axs[i] for i in ['B','D','F','H','J','L']]):
#    #n=11 #(n=7,9,11 are RUL, BT and MIX respectively)
#    sns.regplot(x=svec[ri],y=pcloads[:,(n)],ax=ax)
#    print(str(n)+ ': ' + str(pearsonr(svec[ri],pcloads[:,n])))
for n, ax in enumerate([axs[i] for i in ['A','C','E','G','I','K']]):
    print(str(n)+ ': ' + str(pearsonr(svec[ri],pcloads[:,n])))
    plotting.plot_stat_map(image_list[n], display_mode='x', cut_coords=[50,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=ax)
#plotting.plot_stat_map(image_siddiqi, display_mode='x', cut_coords=[50,27,5], cmap=plt.cm.jet, black_bg=False, symmetric_cbar='auto', colorbar=True, axes=axs['Z'])    

#axs['X'].axis('off')
#axs['Y'].axis('off')
fig.savefig("/resources/REPORTS/Figures/Figure-EF-PCA.svg",format='svg')
# Out:
# 0: (-0.3976212737194181, 0.009117740013171415)
# 1: (-0.10333442201437405, 0.5149042674212058)
# 2: (-0.4424207739334336, 0.003348981731068181)
# 3: (-0.07679833802095008, 0.6288082614996517)
# 4: (-0.060431675188665934, 0.7038187850702348)
# 5: (-0.329594666798622, 0.03304664888164463)

# %%
from scipy.stats import pearsonr
import matplotlib
from matplotlib.colors import ListedColormap
#from matplotlib.colors import ListedColormap
tab10 = matplotlib.colormaps['tab10']
tab10
#modtab10 = ListedColormap(tab10([0,2,1]))
modtab10 = tab10([0,2,1])
modtab10
#volpc=np.concatenate(((pcs[3]*(-1)),pcs[4],pcs[5]), axis=0)
pctemp = np.array([pcs[4][:,0], pcs[4][:,1]*(-1)]).T #9
pctemp2 = np.array([pcs[5][:,0], pcs[5][:,1]*(-1)]).T #11
eftemp = np.array([pcs[0][:,0]*(-1), pcs[0][:,1]]).T#0
volpc=np.concatenate((pcs[3],pctemp,pctemp2), axis=0)
efpc=np.concatenate((eftemp,pcs[1],pcs[2]), axis=0)

outpc = np.concatenate((outcome[3],outcome[4],outcome[5]), axis=0)
plt.rcParams['figure.figsize'] = (7,7);
res = pd.DataFrame(np.concatenate((volpc[:,0:2],efpc[:,0:2],outpc[:,:]), axis=1))
res.columns = ['volpc1', 'volpc2','efpc1', 'efpc2','age','clinresp','pmnt','nECT']

ixmix=np.where(res['pmnt']==1)

res['pmnt-int'] = res['pmnt'].astype('int')
res['madrs'] = 100 * res['clinresp']

fig, axs = plt.subplot_mosaic("XY", figsize=(20,10))

hue_regplot(data=res, x='volpc2', y='madrs', hue='pmnt-int', scatter_kws={'s':75},palette=modtab10, ax=axs['X'])
axs['X'].set_xlabel('Volume change - PC 2')
axs['X'].set_ylabel('MADRS change (%)')


hue_regplot(data=res, x='efpc1', y='madrs', hue='pmnt-int', scatter_kws={'s':75},palette=modtab10, ax=axs['Y'])
axs['Y'].set_xlabel('EF amplitude - PC 1')
axs['Y'].set_ylabel('MADRS change (%)')
axs['X'].spines['top'].set_visible(False)
axs['X'].spines['right'].set_visible(False)
axs['Y'].spines['top'].set_visible(False)
axs['Y'].spines['right'].set_visible(False)

#fig.subplots_adjust(top=0.9)
#fig.suptitle(f + ' Hippocampus')
fig.tight_layout()
fig.savefig("/resources/REPORTS/Figures/Figure-PC-vs-ClinicalResponse.svg",format='svg')

#sns.lmplot(data=res, x='volpc2', y='clinresp', hue='pmnt-int', palette='modtab10')
#hue_regplot(data=res, x='efpc1', y='clinresp', hue='pmnt')

ix=np.where(res['pmnt']<3)
print(pearsonr(res['efpc1'].iloc[ix],res['volpc2'].iloc[ix]))
X=res[['age','volpc1','volpc2','efpc1','efpc2','nECT']].iloc[ix]
#X=res[['age','efpc1','efpc2','nECT']].iloc[ix]
#X=res[['volpc1','volpc2', 'nECT']].iloc[ix]
y=res['clinresp'].iloc[ix]
X = sm.add_constant(X)
model = sm.OLS(y,X).fit()
predictions = model.predict(X)
mr = model.summary2()
mr
#sns.regplot((pcs[3]*(-1))[:,1],outcome[3][:,1])
#pcvf = pcs[3]*(-1)
# Out:
# (-0.18763899235665532, 0.0002092756118022281)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.137
# Dependent Variable: clinresp         AIC:                233.9832
# Date:               2023-05-01 23:26 BIC:                261.6740
# No. Observations:   386              Log-Likelihood:     -109.99
# Df Model:           6                F-statistic:        11.16
# Df Residuals:       379              Prob (F-statistic): 1.80e-11
# R-squared:          0.150            Scale:              0.10543
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -0.3862     0.0786   -4.9160   0.0000   -0.5407   -0.2317
# age       -0.0059     0.0012   -5.0294   0.0000   -0.0081   -0.0036
# volpc1    -0.0030     0.0040   -0.7530   0.4519   -0.0109    0.0049
# volpc2    -0.0177     0.0090   -1.9699   0.0496   -0.0354   -0.0000
# efpc1      0.0060     0.0034    1.7546   0.0801   -0.0007    0.0128
# efpc2      0.0010     0.0082    0.1189   0.9054   -0.0151    0.0170
# nECT       0.0092     0.0032    2.8365   0.0048    0.0028    0.0156
# -----------------------------------------------------------------
# Omnibus:              67.618       Durbin-Watson:          1.852
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       99.773
# Skew:                 1.145        Prob(JB):               0.000
# Kurtosis:             3.978        Condition No.:          275
# =================================================================
#
# """

# %%
import statsmodels.formula.api as smf
pcid = pd.DataFrame(np.concatenate((recordids[0].astype('str'),recordids[1].astype('str'),recordids[2].astype('str'))))
pcid.columns = ['Record ID']
pcid
pcidsex = pcid.merge(ectdf[['Record ID', 'Data Access Group',  'Sex at birth of the participant']].iloc[np.where(ectdf[ 'Sex at birth of the participant'].notnull())].drop_duplicates(), on =  'Record ID', how = 'left')

X = pd.concat((res[['clinresp', 'age','volpc1','volpc2','efpc1','efpc2','nECT','pmnt']],pcidsex[['Data Access Group',  'Sex at birth of the participant']]), ignore_index=True, axis=1)
X.columns=['clinresp', 'age','volpc1','volpc2','efpc1','efpc2','nECT','pmnt','site', 'sex']
#y=res['clinresp']
#X = sm.add_constant(X)
#X
#
#model = smf.ols( formula="clinresp ~ age + volpc1 +volpc2 + efpc1 + efpc2 + nECT + C(pmnt) + C(sex)",data=X).fit()
model = smf.ols( formula="clinresp ~ age + volpc1 +volpc2 + efpc1 + efpc2 + nECT + C(pmnt) + C(sex)",data=X).fit()

predictions = model.predict(X)
mr = model.summary2()
mr
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.171
# Dependent Variable: clinresp         AIC:                221.0227
# Date:               2023-05-02 23:22 BIC:                260.5811
# No. Observations:   386              Log-Likelihood:     -100.51
# Df Model:           9                F-statistic:        9.853
# Df Residuals:       376              Prob (F-statistic): 1.38e-13
# R-squared:          0.191            Scale:              0.10118
# -----------------------------------------------------------------
#                    Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# -----------------------------------------------------------------
# Intercept         -0.3524   0.0807 -4.3691 0.0000 -0.5111 -0.1938
# C(pmnt)[T.1.0]    -0.0082   0.0431 -0.1900 0.8494 -0.0930  0.0766
# C(pmnt)[T.2.0]     0.2004   0.0498  4.0210 0.0001  0.1024  0.2984
# C(sex)[T.M]        0.0299   0.0361  0.8270 0.4087 -0.0411  0.1009
# age               -0.0061   0.0012 -5.2540 0.0000 -0.0084 -0.0038
# volpc1            -0.0013   0.0040 -0.3141 0.7536 -0.0091  0.0066
# volpc2            -0.0214   0.0089 -2.4031 0.0167 -0.0390 -0.0039
# efpc1              0.0072   0.0036  2.0044 0.0457  0.0001  0.0143
# efpc2              0.0011   0.0080  0.1358 0.8920 -0.0147  0.0168
# nECT               0.0042   0.0035  1.1956 0.2326 -0.0027  0.0112
# -----------------------------------------------------------------
# Omnibus:              62.547       Durbin-Watson:          1.924
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       89.495
# Skew:                 1.087        Prob(JB):               0.000
# Kurtosis:             3.916        Condition No.:          294
# =================================================================
#
# """

# %% [markdown]
# ### site as random effect

# %%
model = smf.mixedlm(formula="clinresp ~ age + volpc1 +volpc2 + efpc1 + efpc2 + nECT + C(pmnt) + C(sex)",data=X, groups=X['site']).fit()

predictions = model.predict(X)
mr = model.summary()
mr
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#           Mixed Linear Model Regression Results
# =========================================================
# Model:              MixedLM Dependent Variable: clinresp
# No. Observations:   386     Method:             REML
# No. Groups:         20      Scale:              0.0916
# Min. group size:    2       Log-Likelihood:     -130.9779
# Max. group size:    43      Converged:          Yes
# Mean group size:    19.3
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept      -0.457    0.095 -4.800 0.000 -0.644 -0.271
# C(pmnt)[T.1.0] -0.028    0.062 -0.447 0.655 -0.150  0.094
# C(pmnt)[T.2.0]  0.181    0.051  3.567 0.000  0.082  0.280
# C(sex)[T.M]     0.021    0.035  0.613 0.540 -0.047  0.090
# age            -0.004    0.001 -2.767 0.006 -0.007 -0.001
# volpc1         -0.001    0.004 -0.160 0.873 -0.008  0.007
# volpc2         -0.017    0.009 -1.913 0.056 -0.034  0.000
# efpc1           0.005    0.004  1.485 0.138 -0.002  0.012
# efpc2          -0.000    0.008 -0.024 0.981 -0.016  0.015
# nECT            0.004    0.004  1.025 0.305 -0.003  0.011
# Group Var       0.014    0.024
# =========================================================
#
# """
